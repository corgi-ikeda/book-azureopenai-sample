# %% [markdown]
# <a href="https://colab.research.google.com/github/corgi-ikeda/book-azureopenai-sample/blob/main/Copy_of_Matplotlib_%E6%8F%90%E5%87%BA%E8%AA%B2%E9%A1%8C_editor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib練習問題
#
#  1. Matplotlibについて学習します。(15問)

# %% [markdown]
# **<font color="red">このファイルは、コピーして自分のドライブに保存しなければ、編集が保存されず、課題を提出できません。</font>**
#
# **<font color="red">もしまだコピーしていなければ、「事前準備」レッスンの「Chapter 2
# 演習問題、提出課題について」を参考にしながら、左上の「ファイル」から「ドライブにコピーを保存」を選択して、必ずコピーを保存してください。</font>**

# %% [markdown]
# ## 1. Matplotlibについて学習します。(15問)

# %% [markdown]
# ### 1.1 「日本語を扱えるようにするために、pipコマンドを用いて『japanize-matplotlib』というライブラリをダウンロードしてください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「matplotlibの豆腐化現象を直す方法」節
# </details>

# %%
# !pip install japanize-matplotlib
import japanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 31.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=5823e233758691790dc84eca05191878be5ebb430d9f737c68960f0f86e8aeb0
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize-matplotlib
# ...

# %% [markdown]
# ### 1.2 「japanize_matplotlibをインポートしてください。また、pandas・numpy・matplotlib.pyplot・seabornをそれぞれpd・np・plt・snsという名前で利用できるようにインポートしてください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「ライブラリの読み込み方法」節
# </details>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.3 「次のコードを実行してください。」

# %%
# こちらのセルを実行してください。
data = pd.DataFrame()
np.random.seed(100)
data['身長'] = np.random.normal(170, 7, 100)
data['クラス'] = ['a', 'b', 'c', 'd'] * 25
data['成績'] = [2, 5, 4, 1, 4, 3, 4, 2, 4, 5] * 10
data['体重'] = np.random.normal(60, 3, 100)

data
# Out:
#             身長 クラス  成績         体重
# 0   157.751642   a   2  54.886046
# 1   172.398763   b   5  56.591217
# 2   178.071251   c   4  51.080054
# 3   168.232948   d   1  60.099952
# 4   176.869246   a   4  59.253334
# ..         ...  ..  ..        ...
# 95  170.021122   d   3  61.947519
# 96  169.467836   a   4  59.475655
# 97  170.027703   b   2  63.051793
# 98  168.704901   c   4  58.200051
# 99  152.589939   d   5  64.728500
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 1.4 「dataの『体重』列の分布を、箱ひげ図によって可視化してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」節
# </details>

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(data['体重'])
plt.show()

# %% [markdown]
# ### 1.5 「クラス別の『体重』列の平均値を、棒グラフによって可視化してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」節
# </details>

# %%
plt.figure(figsize=(10, 5))
mean_weights = data.groupby('クラス')['体重'].mean()
plt.bar(mean_weights.index, mean_weights)
plt.show()

# %% [markdown]
# ### 1.6 「身長と体重の関係を、散布図によって可視化してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」節
# </details>

# %%
plt.figure(figsize=(10, 5))
plt.scatter(data['身長'], data['体重'])
plt.show()

# %% [markdown]
# ### 1.7 「1.6の散布図と同様のものを描画してください。その際に、figsizeを(12, 6)のように指定してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」・「各種グラフのオプション設定方法」節
# </details>

# %%
plt.figure(figsize=(12, 6))
plt.scatter(data['身長'], data['体重'])
plt.show()

# %% [markdown]
# ### 1.8 「1.7の散布図と同様のものを描画してください。その際に、タイトルを『身長と体重の関係』、x軸のラベルを『身長』、y軸のラベルを『体重』のように指定してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」・「各種グラフのオプション設定方法」節
# </details>

# %%
plt.figure(figsize=(12, 6))
plt.scatter(data['身長'], data['体重'])
plt.title('身長と体重の関係')
plt.xlabel('身長')
plt.ylabel('体重')
plt.show()

# %% [markdown]
# ### 1.9 「x軸にインデックス、y軸に身長を描画した折れ線グラフを描画してください。その際に、グラフはクラスごとのグラフにして、それぞれに組名のラベルをつけて、凡例を付与してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」・「各種グラフのオプション設定方法」節
# </details>

# %%
plt.figure(figsize=(10, 5))
for class_name, group in data.groupby('クラス'):
    plt.plot(group.index, group['身長'], label=class_name)
plt.legend()
plt.show()

# %% [markdown]
# ### 1.10 「dataの『身長』列の分布を確認するために、クラスA・クラスBの『身長』列についてそれぞれのヒストグラムを描画してください。その際に、グラフの透明度を半透明にしてください。(透明度は好きな値に設定してください。)」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフ作成手順」・「各種グラフの作成方法」・「各種グラフのオプション設定方法」節
# </details>

# %%
plt.figure(figsize=(10, 5))
for class_name, group in data.groupby('クラス'):
    plt.hist(group['身長'], alpha=0.4, label=class_name)

plt.title('身長')
plt.xlabel('身長')
plt.ylabel('人数')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.11 「簡潔な描画方法を用いて、1.4と同様の箱ひげ図を描画してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「簡潔な描画」節
# </details>

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(data['体重'])
plt.title('体重の分布')
plt.xlabel('クラス')
plt.ylabel('体重')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### 1.12 「簡潔な描画方法を用いて、1.8と同様のオプションを持った散布図を描画してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「簡潔な描画」節
# </details>

# %%
plt.figure(figsize=(12, 6))
plt.scatter(data['身長'], data['体重'])
plt.title('身長と体重の関係')
plt.xlabel('身長')
plt.ylabel('体重')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### 1.13 「簡潔な描画方法を用いて、1.9と同様のオプションを付与した折れ線グラフを描画してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「簡潔な描画」節
# </details>

# %%
plt.figure(figsize=(10, 5))
for class_name, group in data.groupby('クラス'):
    plt.plot(group.index, group['身長'], label=class_name)

plt.title('身長')
plt.xlabel('インデックス')
plt.ylabel('身長')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.14 「seabornを用いて、dataの『身長』列のヴァイオリンプロットを描画してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「Seabornによる描画」節
# </details>

# %%
sns.violinplot(x='クラス', y='身長', data=data)
plt.title('身長')
plt.xlabel('クラス')
plt.ylabel('身長')
plt.show()

# %% [markdown]
# ### 1.15 「1.14のグラフを『height_violinplot.png』という名前で保存してください。」

# %% [markdown]
# <details>
# <summary>
# この問題に関連する内容を復習するためのスライド
# </summary>
#
# Matplotlibの「グラフの保存方法について」節
# </details>

# %%
plt.savefig('height_violinplot.png')
